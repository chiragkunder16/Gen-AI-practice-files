# %% [markdown]
# Using LCEL

# %%
# !pip install langchain
# Out:
# Collecting langchain
#   Downloading langchain-1.3.11-py3-none-any.whl.metadata (6.0 kB)
# Collecting langchain-core<2.0.0,>=1.4.7 (from langchain)
#   Using cached langchain_core-1.4.8-py3-none-any.whl.metadata (4.7 kB)
# Collecting langgraph<1.3.0,>=1.2.5 (from langchain)
#   Downloading langgraph-1.2.7-py3-none-any.whl.metadata (4.9 kB)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain)
#   Using cached pydantic-2.13.4-py3-none-any.whl.metadata (109 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.4.7->langchain)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-protocol>=0.0.17 (from langchain-core<2.0.0,>=1.4.7->langchain)
#   Using cached langchain_protocol-0.0.18-py3-none-any.whl.metadata (2.4 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.4.7->langchain)
#   Downloading langsmith-0.9.7-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (26.0)
# Collecting pyyaml<7.0.0,>=5.3.0 (from langchain-core<2.0.0,>=1.4.7->langchain)
#   Using cached pyyaml-6.0.3-cp310-cp310-win_amd64.whl.metadata (2.4 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<2.0.0,>=1.4.7->langchain)
#   Using cached tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\chira\appdata\roaming\python\python310\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (4.16.0)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.4.7->langchain)
#   Downloading uuid_utils-0.16.2-cp310-cp310-win_amd64.whl.metadata (6.5 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.7->langchain)
#   Using cached jsonpointer-3.1.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting langgraph-checkpoint<5.0.0,>=4.1.0 (from langgraph<1.3.0,>=1.2.5->langchain)
#   Downloading langgraph_checkpoint-4.1.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-prebuilt<1.2.0,>=1.1.0 (from langgraph<1.3.0,>=1.2.5->langchain)
#   Using cached langgraph_prebuilt-1.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.5.0,>=0.4.2 (from langgraph<1.3.0,>=1.2.5->langchain)
#   Downloading langgraph_sdk-0.4.2-py3-none-any.whl.metadata (3.6 kB)
# Collecting xxhash>=3.5.0 (from langgraph<1.3.0,>=1.2.5->langchain)
#   Downloading xxhash-3.8.1-cp310-cp310-win_amd64.whl.metadata (15 kB)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.5->langchain)
#   Using cached ormsgpack-1.12.2-cp310-cp310-win_amd64.whl.metadata (3.3 kB)
# Collecting httpx>=0.25.2 (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting orjson>=3.11.5 (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain)
#   Using cached orjson-3.11.9-cp310-cp310-win_amd64.whl.metadata (43 kB)
# Collecting websockets<16,>=14 (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain)
#   Downloading websockets-15.0.1-cp310-cp310-win_amd64.whl.metadata (7.0 kB)
# Collecting anyio>=3.5.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain)
#   Downloading anyio-4.14.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting distro>=1.7.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting requests>=2.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain)
#   Using cached requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# Collecting sniffio>=1.1 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain)
#   Using cached zstandard-0.25.0-cp310-cp310-win_amd64.whl.metadata (3.3 kB)
# Collecting certifi (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain)
#   Downloading certifi-2026.6.17-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting idna (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain)
#   Downloading idna-3.18-py3-none-any.whl.metadata (6.1 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.46.4 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Using cached pydantic_core-2.46.4-cp310-cp310-win_amd64.whl.metadata (6.7 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\chira\appdata\roaming\python\python310\site-packages (from anyio>=3.5.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (1.3.1)
# Collecting charset_normalizer<4,>=2 (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain)
#   Downloading charset_normalizer-3.4.8-cp310-cp310-win_amd64.whl.metadata (42 kB)
# Collecting urllib3<3,>=1.26 (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain)
#   Using cached urllib3-2.7.0-py3-none-any.whl.metadata (6.9 kB)
# Downloading langchain-1.3.11-py3-none-any.whl (133 kB)
# Using cached langchain_core-1.4.8-py3-none-any.whl (557 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langgraph-1.2.7-py3-none-any.whl (246 kB)
# Downloading langgraph_checkpoint-4.1.1-py3-none-any.whl (56 kB)
# Using cached langgraph_prebuilt-1.1.0-py3-none-any.whl (41 kB)
# Downloading langgraph_sdk-0.4.2-py3-none-any.whl (160 kB)
# Downloading langsmith-0.9.7-py3-none-any.whl (671 kB)
#    ---------------------------------------- 0.0/671.1 kB ? eta -:--:--
#    ---------------------------------------- 671.1/671.1 kB 5.2 MB/s  0:00:00
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached pydantic-2.13.4-py3-none-any.whl (472 kB)
# Using cached pydantic_core-2.46.4-cp310-cp310-win_amd64.whl (2.1 MB)
# Using cached pyyaml-6.0.3-cp310-cp310-win_amd64.whl (158 kB)
# Using cached tenacity-9.1.4-py3-none-any.whl (28 kB)
# Downloading uuid_utils-0.16.2-cp310-cp310-win_amd64.whl (176 kB)
# Downloading websockets-15.0.1-cp310-cp310-win_amd64.whl (176 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading anyio-4.14.1-py3-none-any.whl (124 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading idna-3.18-py3-none-any.whl (65 kB)
# Using cached jsonpointer-3.1.1-py3-none-any.whl (7.7 kB)
# Using cached langchain_protocol-0.0.18-py3-none-any.whl (7.2 kB)
# Using cached orjson-3.11.9-cp310-cp310-win_amd64.whl (127 kB)
# Using cached ormsgpack-1.12.2-cp310-cp310-win_amd64.whl (117 kB)
# Using cached requests-2.34.2-py3-none-any.whl (73 kB)
# Downloading charset_normalizer-3.4.8-cp310-cp310-win_amd64.whl (162 kB)
# Using cached urllib3-2.7.0-py3-none-any.whl (131 kB)
# Downloading certifi-2026.6.17-py3-none-any.whl (133 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading xxhash-3.8.1-cp310-cp310-win_amd64.whl (32 kB)
# Using cached zstandard-0.25.0-cp310-cp310-win_amd64.whl (506 kB)
# Installing collected packages: zstandard, xxhash, websockets, uuid-utils, urllib3, typing-inspection, tenacity, sniffio, pyyaml, pydantic-core, ormsgpack, orjson, langchain-protocol, jsonpointer, idna, h11, distro, charset_normalizer, certifi, annotated-types, requests, pydantic, jsonpatch, httpcore, anyio, requests-toolbelt, httpx, langsmith, langchain-core, langgraph-sdk, langgraph-checkpoint, langgraph-prebuilt, langgraph, langchain
#
#    -- -------------------------------------  2/34 [websockets]
#    -- -------------------------------------  2/34 [websockets]
#    -- -------------------------------------  2/34 [websockets]
#    -- -------------------------------------  2/34 [websockets]
#    -- -------------------------------------  2/34 [websockets]
#    ---- -----------------------------------  4/34 [urllib3]
#    ---- -----------------------------------  4/34 [urllib3]
#    ---- -----------------------------------  4/34 [urllib3]
#    ---- -----------------------------------  4/34 [urllib3]
#    ------- --------------------------------  6/34 [tenacity]
#    -------- -------------------------------  7/34 [sniffio]
#    --------- ------------------------------  8/34 [pyyaml]
#    --------- ------------------------------  8/34 [pyyaml]
#    ----------- ---------------------------- 10/34 [ormsgpack]
#    --------------- ------------------------ 13/34 [jsonpointer]
#    ---------------- ----------------------- 14/34 [idna]
#    ----------------- ---------------------- 15/34 [h11]
#    ----------------- ---------------------- 15/34 [h11]
#    -------------------- ------------------- 17/34 [charset_normalizer]
#    -------------------- ------------------- 17/34 [charset_normalizer]
#    --------------------- ------------------ 18/34 [certifi]
#    ----------------------- ---------------- 20/34 [requests]
#    ----------------------- ---------------- 20/34 [requests]
#    ------------------------ --------------- 21/34 [pydantic]
#    ------------------------ --------------- 21/34 [pydantic]
#    ------------------------ --------------- 21/34 [pydantic]
#    ------------------------ --------------- 21/34 [pydantic]
#    ------------------------ --------------- 21/34 [pydantic]
#    ------------------------ --------------- 21/34 [pydantic]
#    ------------------------ --------------- 21/34 [pydantic]
#    ------------------------ --------------- 21/34 [pydantic]
#    ------------------------ --------------- 21/34 [pydantic]
#    ------------------------ --------------- 21/34 [pydantic]
#    ------------------------ --------------- 21/34 [pydantic]
#    ------------------------ --------------- 21/34 [pydantic]
#    --------------------------- ------------ 23/34 [httpcore]
#    --------------------------- ------------ 23/34 [httpcore]
#    --------------------------- ------------ 23/34 [httpcore]
#    ---------------------------- ----------- 24/34 [anyio]
#    ---------------------------- ----------- 24/34 [anyio]
#    ---------------------------- ----------- 24/34 [anyio]
#    ---------------------------- ----------- 24/34 [anyio]
#    ---------------------------- ----------- 24/34 [anyio]
#    ----------------------------- ---------- 25/34 [requests-toolbelt]
#    ----------------------------- ---------- 25/34 [requests-toolbelt]
#    ----------------------------- ---------- 25/34 [requests-toolbelt]
#    ------------------------------ --------- 26/34 [httpx]
#    ------------------------------ --------- 26/34 [httpx]
#    ------------------------------ --------- 26/34 [httpx]
#    ------------------------------ --------- 26/34 [httpx]
#    ------------------------------- -------- 27/34 [langsmith]
#    ------------------------------- -------- 27/34 [langsmith]
#    ------------------------------- -------- 27/34 [langsmith]
#    ------------------------------- -------- 27/34 [langsmith]
#    ------------------------------- -------- 27/34 [langsmith]
#    ------------------------------- -------- 27/34 [langsmith]
#    ------------------------------- -------- 27/34 [langsmith]
#    ------------------------------- -------- 27/34 [langsmith]
#    ------------------------------- -------- 27/34 [langsmith]
#    ------------------------------- -------- 27/34 [langsmith]
#    ------------------------------- -------- 27/34 [langsmith]
#    ------------------------------- -------- 27/34 [langsmith]
#    ------------------------------- -------- 27/34 [langsmith]
#    ------------------------------- -------- 27/34 [langsmith]
#    ------------------------------- -------- 27/34 [langsmith]
#    ------------------------------- -------- 27/34 [langsmith]
#    ------------------------------- -------- 27/34 [langsmith]
#    ------------------------------- -------- 27/34 [langsmith]
#    ------------------------------- -------- 27/34 [langsmith]
#    ------------------------------- -------- 27/34 [langsmith]
#    ------------------------------- -------- 27/34 [langsmith]
#    ------------------------------- -------- 27/34 [langsmith]
#    ------------------------------- -------- 27/34 [langsmith]
#    ------------------------------- -------- 27/34 [langsmith]
#    ------------------------------- -------- 27/34 [langsmith]
#    ------------------------------- -------- 27/34 [langsmith]
#    ------------------------------- -------- 27/34 [langsmith]
#    -------------------------------- ------- 28/34 [langchain-core]
#    -------------------------------- ------- 28/34 [langchain-core]
#    -------------------------------- ------- 28/34 [langchain-core]
#    -------------------------------- ------- 28/34 [langchain-core]
#    -------------------------------- ------- 28/34 [langchain-core]
#    -------------------------------- ------- 28/34 [langchain-core]
#    -------------------------------- ------- 28/34 [langchain-core]
#    -------------------------------- ------- 28/34 [langchain-core]
#    -------------------------------- ------- 28/34 [langchain-core]
#    -------------------------------- ------- 28/34 [langchain-core]
#    -------------------------------- ------- 28/34 [langchain-core]
#    -------------------------------- ------- 28/34 [langchain-core]
#    -------------------------------- ------- 28/34 [langchain-core]
#    -------------------------------- ------- 28/34 [langchain-core]
#    -------------------------------- ------- 28/34 [langchain-core]
#    -------------------------------- ------- 28/34 [langchain-core]
#    -------------------------------- ------- 28/34 [langchain-core]
#    ---------------------------------- ----- 29/34 [langgraph-sdk]
#    ---------------------------------- ----- 29/34 [langgraph-sdk]
#    ---------------------------------- ----- 29/34 [langgraph-sdk]
#    ---------------------------------- ----- 29/34 [langgraph-sdk]
#    ---------------------------------- ----- 29/34 [langgraph-sdk]
#    ----------------------------------- ---- 30/34 [langgraph-checkpoint]
#    ----------------------------------- ---- 30/34 [langgraph-checkpoint]
#    ------------------------------------ --- 31/34 [langgraph-prebuilt]
#    ------------------------------------- -- 32/34 [langgraph]
#    ------------------------------------- -- 32/34 [langgraph]
#    ------------------------------------- -- 32/34 [langgraph]
#    ------------------------------------- -- 32/34 [langgraph]
#    ------------------------------------- -- 32/34 [langgraph]
#    ------------------------------------- -- 32/34 [langgraph]
#    ------------------------------------- -- 32/34 [langgraph]
#    ------------------------------------- -- 32/34 [langgraph]
#    ------------------------------------- -- 32/34 [langgraph]
#    ------------------------------------- -- 32/34 [langgraph]
#    -------------------------------------- - 33/34 [langchain]
#    -------------------------------------- - 33/34 [langchain]
#    -------------------------------------- - 33/34 [langchain]
#    ---------------------------------------- 34/34 [langchain]
#
# Successfully installed annotated-types-0.7.0 anyio-4.14.1 certifi-2026.6.17 charset_normalizer-3.4.8 distro-1.9.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.18 jsonpatch-1.33 jsonpointer-3.1.1 langchain-1.3.11 langchain-core-1.4.8 langchain-protocol-0.0.18 langgraph-1.2.7 langgraph-checkpoint-4.1.1 langgraph-prebuilt-1.1.0 langgraph-sdk-0.4.2 langsmith-0.9.7 orjson-3.11.9 ormsgpack-1.12.2 pydantic-2.13.4 pydantic-core-2.46.4 pyyaml-6.0.3 requests-2.34.2 requests-toolbelt-1.0.0 sniffio-1.3.1 tenacity-9.1.4 typing-inspection-0.4.2 urllib3-2.7.0 uuid-utils-0.16.2 websockets-15.0.1 xxhash-3.8.1 zstandard-0.25.0

# %%
# !pip install python-dotenv

# %%
### Open AI API Key and Open Source models---Llama3,Gemma2,mistral--Groq

import os 
from dotenv import load_dotenv
load_dotenv()

# import openai
# openai.api_key=os.getenv("OPENAI_API_KEY")

groq_api_key=os.getenv("GROQ_API_KEY")

# %%
# !pip install langchain_groq
# Out:
# Collecting langchain_groq
#   Using cached langchain_groq-1.1.3-py3-none-any.whl.metadata (2.9 kB)
# Collecting groq<1.0.0,>=0.30.0 (from langchain_groq)
#   Using cached groq-0.37.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langchain_groq) (1.4.8)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (4.14.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (2.13.4)
# Requirement already satisfied: sniffio in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in c:\users\chira\appdata\roaming\python\python310\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (4.16.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\chira\appdata\roaming\python\python310\site-packages (from anyio<5,>=3.5.0->groq<1.0.0,>=0.30.0->langchain_groq) (1.3.1)
# Requirement already satisfied: idna>=2.8 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from anyio<5,>=3.5.0->groq<1.0.0,>=0.30.0->langchain_groq) (3.18)
# Requirement already satisfied: certifi in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_groq) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_groq) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_groq) (0.9.7)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_groq) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_groq) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_groq) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_groq) (0.16.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain_groq) (3.1.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_groq) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_groq) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_groq) (2.34.2)
# Requirement already satisfied: websockets>=15.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_groq) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_groq) (3.8.1)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_groq) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain_groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain_groq) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain_groq) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_groq) (3.4.8)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_groq) (2.7.0)
# Using cached langchain_groq-1.1.3-py3-none-any.whl (20 kB)
# Using cached groq-0.37.1-py3-none-any.whl (137 kB)
# Installing collected packages: groq, langchain_groq
#
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    -------------------- ------------------- 1/2 [langchain_groq]
#    ---------------------------------------- 2/2 [langchain_groq]
#
# Successfully installed groq-0.37.1 langchain_groq-1.1.3

# %%
from langchain_groq import ChatGroq
model=ChatGroq(model="llama-3.1-8b-instant",groq_api_key=groq_api_key)
model
# Out:
# ChatGroq(metadata={'lc_versions': {'langchain-core': '1.4.8', 'langchain': '1.3.11'}}, output_version=None, profile={'name': 'Llama 3.1 8B Instant', 'release_date': '2024-07-23', 'last_updated': '2024-07-23', 'open_weights': True, 'max_input_tokens': 131072, 'max_output_tokens': 131072, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'attachment': False, 'temperature': True}, client=<groq.resources.chat.completions.Completions object at 0x000001EB072C70D0>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000001EB04A3C400>, model_name='llama-3.1-8b-instant', model_kwargs={}, groq_api_key=SecretStr('**********'), groq_api_base=None, groq_proxy=None)

# %%
# !pip install langchain_core
# Out:
# Requirement already satisfied: langchain_core in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (1.4.8)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langchain_core) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langchain_core) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langchain_core) (0.9.7)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langchain_core) (26.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langchain_core) (2.13.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langchain_core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langchain_core) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\chira\appdata\roaming\python\python310\site-packages (from langchain_core) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langchain_core) (0.16.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain_core) (3.1.1)
# Requirement already satisfied: anyio>=3.5.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (4.14.1)
# Requirement already satisfied: distro>=1.7.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (3.8.1)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (0.25.0)
# Requirement already satisfied: certifi in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (1.0.9)
# Requirement already satisfied: idna in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (3.18)
# Requirement already satisfied: h11>=0.16 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (0.4.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\chira\appdata\roaming\python\python310\site-packages (from anyio>=3.5.0->langsmith<1.0.0,>=0.3.45->langchain_core) (1.3.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain_core) (3.4.8)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain_core) (2.7.0)

# %%
# !pip install langchain_community
# Out:
# Collecting langchain_community
#   Downloading langchain_community-0.4.2-py3-none-any.whl.metadata (3.4 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain_community)
#   Downloading aiohttp-3.14.1-cp310-cp310-win_amd64.whl.metadata (8.5 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain_community)
#   Using cached httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Collecting langchain-classic<2.0.0,>=1.0.7 (from langchain_community)
#   Downloading langchain_classic-1.0.8-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langchain_community) (1.4.8)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langchain_community) (0.9.7)
# Collecting numpy>=1.26.2 (from langchain_community)
#   Using cached numpy-2.2.6-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain_community)
#   Downloading pydantic_settings-2.14.2-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langchain_community) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langchain_community) (2.34.2)
# Collecting sqlalchemy<3.0.0,>=1.4.0 (from langchain_community)
#   Downloading sqlalchemy-2.0.51-cp310-cp310-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langchain_community) (9.1.4)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading aiohappyeyeballs-2.7.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting async-timeout<6.0,>=4.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached async_timeout-5.0.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached attrs-26.1.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached frozenlist-1.8.0-cp310-cp310-win_amd64.whl.metadata (21 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached multidict-6.7.1-cp310-cp310-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached propcache-0.5.2-cp310-cp310-win_amd64.whl.metadata (17 kB)
# Requirement already satisfied: typing_extensions>=4.4 in c:\users\chira\appdata\roaming\python\python310\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (4.16.0)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached yarl-1.24.2-cp310-cp310-win_amd64.whl.metadata (97 kB)
# Collecting async-timeout<6.0,>=4.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting langchain-text-splitters<2.0.0,>=1.1.2 (from langchain-classic<2.0.0,>=1.0.7->langchain_community)
#   Using cached langchain_text_splitters-1.1.2-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain_community) (2.13.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_community) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_community) (0.0.18)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_community) (26.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_community) (0.16.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain_community) (3.1.1)
# Requirement already satisfied: anyio>=3.5.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (4.14.1)
# Requirement already satisfied: distro>=1.7.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.8.1)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.25.0)
# Requirement already satisfied: certifi in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: idna in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (3.18)
# Requirement already satisfied: h11>=0.16 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain_community) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain_community) (0.4.2)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.10.1->langchain_community)
#   Using cached python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.4.8)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\chira\onedrive\desktop\gen-ai-practice-files\venv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2.7.0)
# Collecting greenlet>=1 (from sqlalchemy<3.0.0,>=1.4.0->langchain_community)
#   Downloading greenlet-3.5.3-cp310-cp310-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\chira\appdata\roaming\python\python310\site-packages (from anyio>=3.5.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.3.1)
# Downloading langchain_community-0.4.2-py3-none-any.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.4 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.4 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.4 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.4 MB 349.5 kB/s eta 0:00:06
#    -------- ------------------------------- 0.5/2.4 MB 349.5 kB/s eta 0:00:06
#    -------- ------------------------------- 0.5/2.4 MB 349.5 kB/s eta 0:00:06
#    -------- ------------------------------- 0.5/2.4 MB 349.5 kB/s eta 0:00:06
#    ------------- -------------------------- 0.8/2.4 MB 332.2 kB/s eta 0:00:05
#    ------------- -------------------------- 0.8/2.4 MB 332.2 kB/s eta 0:00:05
#    ------------- -------------------------- 0.8/2.4 MB 332.2 kB/s eta 0:00:05
#    ------------- -------------------------- 0.8/2.4 MB 332.2 kB/s eta 0:00:05
#    ------------- -------------------------- 0.8/2.4 MB 332.2 kB/s eta 0:00:05
#    ------------- -------------------------- 0.8/2.4 MB 332.2 kB/s eta 0:00:05
#    ----------------- ---------------------- 1.0/2.4 MB 292.6 kB/s eta 0:00:05
#    ----------------- ---------------------- 1.0/2.4 MB 292.6 kB/s eta 0:00:05
#    ----------------- ---------------------- 1.0/2.4 MB 292.6 kB/s eta 0:00:05
#    ----------------- ---------------------- 1.0/2.4 MB 292.6 kB/s eta 0:00:05
#    ----------------- ---------------------- 1.0/2.4 MB 292.6 kB/s eta 0:00:05
#    ----------------- ---------------------- 1.0/2.4 MB 292.6 kB/s eta 0:00:05
#    ----------------- ---------------------- 1.0/2.4 MB 292.6 kB/s eta 0:00:05
#    ---------------------- ----------------- 1.3/2.4 MB 244.9 kB/s eta 0:00:05
#    ---------------------- ----------------- 1.3/2.4 MB 244.9 kB/s eta 0:00:05
#    ---------------------- ----------------- 1.3/2.4 MB 244.9 kB/s eta 0:00:05
#    ---------------------- ----------------- 1.3/2.4 MB 244.9 kB/s eta 0:00:05
#    ---------------------- ----------------- 1.3/2.4 MB 244.9 kB/s eta 0:00:05
#    ---------------------- ----------------- 1.3/2.4 MB 244.9 kB/s eta 0:00:05
#    ---------------------- ----------------- 1.3/2.4 MB 244.9 kB/s eta 0:00:05
#    ---------------------- ----------------- 1.3/2.4 MB 244.9 kB/s eta 0:00:05
#    ---------------------- ----------------- 1.3/2.4 MB 244.9 kB/s eta 0:00:05
#    -------------------------- ------------- 1.6/2.4 MB 214.0 kB/s eta 0:00:04
#    -------------------------- ------------- 1.6/2.4 MB 214.0 kB/s eta 0:00:04
#    -------------------------- ------------- 1.6/2.4 MB 214.0 kB/s eta 0:00:04
#    -------------------------- ------------- 1.6/2.4 MB 214.0 kB/s eta 0:00:04
#    -------------------------- ------------- 1.6/2.4 MB 214.0 kB/s eta 0:00:04
#    -------------------------- ------------- 1.6/2.4 MB 214.0 kB/s eta 0:00:04
#    -------------------------- ------------- 1.6/2.4 MB 214.0 kB/s eta 0:00:04
#    -------------------------- ------------- 1.6/2.4 MB 214.0 kB/s eta 0:00:04
#    -------------------------- ------------- 1.6/2.4 MB 214.0 kB/s eta 0:00:04
#    -------------------------- ------------- 1.6/2.4 MB 214.0 kB/s eta 0:00:04
#    ------------------------------- -------- 1.8/2.4 MB 193.2 kB/s eta 0:00:03
#    ------------------------------- -------- 1.8/2.4 MB 193.2 kB/s eta 0:00:03
#    ------------------------------- -------- 1.8/2.4 MB 193.2 kB/s eta 0:00:03
#    ------------------------------- -------- 1.8/2.4 MB 193.2 kB/s eta 0:00:03
#    ------------------------------- -------- 1.8/2.4 MB 193.2 kB/s eta 0:00:03
#    ------------------------------- -------- 1.8/2.4 MB 193.2 kB/s eta 0:00:03
#    ------------------------------- -------- 1.8/2.4 MB 193.2 kB/s eta 0:00:03
#    ------------------------------- -------- 1.8/2.4 MB 193.2 kB/s eta 0:00:03
#    ----------------------------------- ---- 2.1/2.4 MB 183.5 kB/s eta 0:00:02
#    ----------------------------------- ---- 2.1/2.4 MB 183.5 kB/s eta 0:00:02
#    ----------------------------------- ---- 2.1/2.4 MB 183.5 kB/s eta 0:00:02
#    ----------------------------------- ---- 2.1/2.4 MB 183.5 kB/s eta 0:00:02
#    ----------------------------------- ---- 2.1/2.4 MB 183.5 kB/s eta 0:00:02
#    ----------------------------------- ---- 2.1/2.4 MB 183.5 kB/s eta 0:00:02
#    ----------------------------------- ---- 2.1/2.4 MB 183.5 kB/s eta 0:00:02
#    ----------------------------------- ---- 2.1/2.4 MB 183.5 kB/s eta 0:00:02
#    ----------------------------------- ---- 2.1/2.4 MB 183.5 kB/s eta 0:00:02
#    ----------------------------------- ---- 2.1/2.4 MB 183.5 kB/s eta 0:00:02
#    ----------------------------------- ---- 2.1/2.4 MB 183.5 kB/s eta 0:00:02
#    ----------------------------------- ---- 2.1/2.4 MB 183.5 kB/s eta 0:00:02
#    ---------------------------------------- 2.4/2.4 MB 168.6 kB/s  0:00:13
# Downloading aiohttp-3.14.1-cp310-cp310-win_amd64.whl (482 kB)
# Using cached httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Downloading langchain_classic-1.0.8-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    -------------------- ------------------- 0.5/1.0 MB 132.1 kB/s eta 0:00:04
#    -------------------- ------------------- 0.5/1.0 MB 132.1 kB/s eta 0:00:04
#    -------------------- ------------------- 0.5/1.0 MB 132.1 kB/s eta 0:00:04
#    -------------------- ------------------- 0.5/1.0 MB 132.1 kB/s eta 0:00:04
#    -------------------- ------------------- 0.5/1.0 MB 132.1 kB/s eta 0:00:04
#    -------------------- ------------------- 0.5/1.0 MB 132.1 kB/s eta 0:00:04
#    ------------------------------ --------- 0.8/1.0 MB 164.5 kB/s eta 0:00:02
#    ------------------------------ --------- 0.8/1.0 MB 164.5 kB/s eta 0:00:02
#    ------------------------------ --------- 0.8/1.0 MB 164.5 kB/s eta 0:00:02
#    ------------------------------ --------- 0.8/1.0 MB 164.5 kB/s eta 0:00:02
#    ------------------------------ --------- 0.8/1.0 MB 164.5 kB/s eta 0:00:02
#    ------------------------------ --------- 0.8/1.0 MB 164.5 kB/s eta 0:00:02
#    ---------------------------------------- 1.0/1.0 MB 171.4 kB/s  0:00:06
# Using cached async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Using cached langchain_text_splitters-1.1.2-py3-none-any.whl (35 kB)
# Using cached multidict-6.7.1-cp310-cp310-win_amd64.whl (46 kB)
# Downloading pydantic_settings-2.14.2-py3-none-any.whl (61 kB)
# Downloading sqlalchemy-2.0.51-cp310-cp310-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.1 MB 441.3 kB/s eta 0:00:04
#    --------- ------------------------------ 0.5/2.1 MB 441.3 kB/s eta 0:00:04
#    --------- ------------------------------ 0.5/2.1 MB 441.3 kB/s eta 0:00:04
#    --------- ------------------------------ 0.5/2.1 MB 441.3 kB/s eta 0:00:04
#    -------------- ------------------------- 0.8/2.1 MB 390.1 kB/s eta 0:00:04
#    -------------- ------------------------- 0.8/2.1 MB 390.1 kB/s eta 0:00:04
#    -------------- ------------------------- 0.8/2.1 MB 390.1 kB/s eta 0:00:04
#    -------------- ------------------------- 0.8/2.1 MB 390.1 kB/s eta 0:00:04
#    -------------- ------------------------- 0.8/2.1 MB 390.1 kB/s eta 0:00:04
#    ------------------- -------------------- 1.0/2.1 MB 333.2 kB/s eta 0:00:04
#    ------------------------ --------------- 1.3/2.1 MB 390.1 kB/s eta 0:00:03
#    ----------------------------- ---------- 1.6/2.1 MB 451.0 kB/s eta 0:00:02
#    ----------------------------- ---------- 1.6/2.1 MB 451.0 kB/s eta 0:00:02
#    ----------------------------- ---------- 1.6/2.1 MB 451.0 kB/s eta 0:00:02
#    ---------------------------------- ----- 1.8/2.1 MB 447.3 kB/s eta 0:00:01
#    ---------------------------------- ----- 1.8/2.1 MB 447.3 kB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 467.9 kB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 470.8 kB/s  0:00:04
# Using cached yarl-1.24.2-cp310-cp310-win_amd64.whl (92 kB)
# Downloading aiohappyeyeballs-2.7.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached attrs-26.1.0-py3-none-any.whl (67 kB)
# Using cached frozenlist-1.8.0-cp310-cp310-win_amd64.whl (43 kB)
# Downloading greenlet-3.5.3-cp310-cp310-win_amd64.whl (238 kB)
# Using cached numpy-2.2.6-cp310-cp310-win_amd64.whl (12.9 MB)
# Using cached propcache-0.5.2-cp310-cp310-win_amd64.whl (42 kB)
# Using cached python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Installing collected packages: python-dotenv, propcache, numpy, multidict, httpx-sse, greenlet, frozenlist, attrs, async-timeout, aiohappyeyeballs, yarl, sqlalchemy, aiosignal, pydantic-settings, aiohttp, langchain-text-splitters, langchain-classic, langchain_community
#
#    ----------------------------------------  0/18 [python-dotenv]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ---- -----------------------------------  2/18 [numpy]
#    ------ ---------------------------------  3/18 [multidict]
#    -------- -------------------------------  4/18 [httpx-sse]
#    ----------- ----------------------------  5/18 [greenlet]
#    ----------- ----------------------------  5/18 [greenlet]
#    ----------- ----------------------------  5/18 [greenlet]
#    --------------- ------------------------  7/18 [attrs]
#    --------------- ------------------------  7/18 [attrs]
#    --------------- ------------------------  7/18 [attrs]
#    -------------------- -------------------  9/18 [aiohappyeyeballs]
#    ---------------------- ----------------- 10/18 [yarl]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ------------------------ --------------- 11/18 [sqlalchemy]
#    ---------------------------- ----------- 13/18 [pydantic-settings]
#    ---------------------------- ----------- 13/18 [pydantic-settings]
#    ------------------------------- -------- 14/18 [aiohttp]
#    ------------------------------- -------- 14/18 [aiohttp]
#    ------------------------------- -------- 14/18 [aiohttp]
#    ------------------------------- -------- 14/18 [aiohttp]
#    ------------------------------- -------- 14/18 [aiohttp]
#    ------------------------------- -------- 14/18 [aiohttp]
#    ------------------------------- -------- 14/18 [aiohttp]
#    ------------------------------- -------- 14/18 [aiohttp]
#    ------------------------------- -------- 14/18 [aiohttp]
#    --------------------------------- ------ 15/18 [langchain-text-splitters]
#    --------------------------------- ------ 15/18 [langchain-text-splitters]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ----------------------------------- ---- 16/18 [langchain-classic]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ------------------------------------- -- 17/18 [langchain_community]
#    ---------------------------------------- 18/18 [langchain_community]
#
# Successfully installed aiohappyeyeballs-2.7.1 aiohttp-3.14.1 aiosignal-1.4.0 async-timeout-4.0.3 attrs-26.1.0 frozenlist-1.8.0 greenlet-3.5.3 httpx-sse-0.4.3 langchain-classic-1.0.8 langchain-text-splitters-1.1.2 langchain_community-0.4.2 multidict-6.7.1 numpy-2.2.6 propcache-0.5.2 pydantic-settings-2.14.2 python-dotenv-1.2.2 sqlalchemy-2.0.51 yarl-1.24.2

# %%
from langchain_core.messages import HumanMessage, SystemMessage

messages = [
    SystemMessage(content="Translate the following from English to French"),
    HumanMessage(content="Hello How are you?")
]

result=model.invoke(messages)
print(result)
# Out:
# content='Bonjour Comment allez-vous ?' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 7, 'prompt_tokens': 47, 'total_tokens': 54, 'completion_time': 0.01708496, 'completion_tokens_details': None, 'prompt_time': 0.003551033, 'prompt_tokens_details': None, 'queue_time': 0.050434896, 'total_time': 0.020635993}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019f4ab0-82b1-78b3-9e9c-5a3cf3e0bbb5-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 47, 'output_tokens': 7, 'total_tokens': 54}

# %%
from langchain_core.output_parsers import StrOutputParser
parser = StrOutputParser()
parser.invoke(result)
# Out:
# 'Bonjour Comment allez-vous ?'

# %%
#Using LCEL we can chain the components

chain=model | parser
chain.invoke(messages)
# Out:
# 'Bonjour Comment allez-vous ?'

# %%
##Prompt Templates

from langchain_core.prompts import ChatPromptTemplate

generic_template = "Translate the following into {language}"

prompt = ChatPromptTemplate.from_messages(
    [("system",generic_template),("user","{text}")]
)

# %%
result = prompt.invoke({"language":"French","text":"Hello"})
result.to_messages()
# Out:
# [SystemMessage(content='Translate the following into French', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='Hello', additional_kwargs={}, response_metadata={})]

# %%
#Chaining together components with LCEL

chain=prompt|model|parser
chain.invoke({"language":"French","text":"Hello"})
# Out:
# 'Bonjour'
